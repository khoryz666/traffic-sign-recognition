# %%
#Import the libraries
import os     #auto processes every image in subfolders
import cv2
import numpy as np
import pandas as pd

# %%
input_folder = "Inputs"

for colour in ["Red Signs", "Blue Signs", "Yellow Signs"]:

    folder = os.path.join(input_folder, colour)

    for filename in os.listdir(folder):

        if filename.lower().endswith((".jpg", ".png", ".jpeg")):

            image_path = os.path.join(folder, filename)

            img = cv2.imread(image_path)

            print(f"Processing {colour}: {filename}")

            # Colour segmentation
            # Shape detection
# Out:
# Processing Red Signs: 000_1_0002.png
# Processing Red Signs: 000_1_0013.png
# Processing Red Signs: 000_1_0018.png
# Processing Red Signs: 000_1_0034.png
# Processing Red Signs: 001_0004.png
# Processing Red Signs: 001_1_0009.png
# Processing Red Signs: 002_0036.png
# Processing Red Signs: 002_1_0010.png
# Processing Red Signs: 003_1_0034.png
# Processing Red Signs: 004_1_0020.png
# Processing Red Signs: 005_0030.png
# Processing Red Signs: 005_1_0027.png
# Processing Red Signs: 007_1_0006.png
# Processing Red Signs: 008_1_0008_1_j.png
# Processing Red Signs: 010_1_0013.png
# Processing Red Signs: 011_0029.png
# Processing Red Signs: 011_1_0019.png
# Processing Red Signs: 012_1_0015.png
# Processing Red Signs: 013_0013.png
# Processing Red Signs: 014_1_0028.png
# Processing Red Signs: 015_1_0001.png
# Processing Red Signs: 016_1_0014.png
# Processing Red Signs: 017_1_0017.png
# Processing Red Signs: 033_1_0001.png
# Processing Red Signs: 052_1_0008_1_j.png
# Processing Red Signs: 055_1_0031.png
# Processing Red Signs: 056_1_0010.png
# Processing Red Signs: 057_0003_j.png
# Processing Blue Signs: 020_0002_j.png
# Processing Blue Signs: 020_0003.png
# Processing Blue Signs: 020_0004.png
# Processing Blue Signs: 020_0006.png
# Processing Blue Signs: 021_0002_j.png
# Processing Blue Signs: 021_0003.png
# Processing Blue Signs: 021_0004.png
# Processing Blue Signs: 021_0004_j.png
# Processing Blue Signs: 022_0005.png
# Processing Blue Signs: 023_1_0002_1_j.png
# Processing Blue Signs: 023_1_0003.png
# Processing Blue Signs: 023_1_0004.png
# Processing Blue Signs: 023_1_0005.png
# Processing Blue Signs: 024_1_0016.png
# Processing Blue Signs: 024_1_0017.png
# Processing Blue Signs: 026_1_0016.png
# Processing Blue Signs: 027_0002.png
# Processing Blue Signs: 027_0010.png
# Processing Blue Signs: 027_0012.png
# Processing Blue Signs: 028_0202.png
# Processing Blue Signs: 028_1_0007.png
# Processing Blue Signs: 028_1_0216.png
# Processing Blue Signs: 029_1_0015.png
# Processing Blue Signs: 030_1_0002.png
# Processing Blue Signs: 030_1_0018_1_j.png
# Processing Blue Signs: 030_1_0023.png
# Processing Blue Signs: 031_0011.png
# Processing Blue Signs: 031_1_0020.png
# Processing Yellow Signs: 032_1_0001_1_j.png
# Processing Yellow Signs: 032_1_0002_1_j.png
# Processing Yellow Signs: 034_1_0002.png
# Processing Yellow Signs: 034_1_0003_1_j.png
# Processing Yellow Signs: 035_1_0002.png
# Processing Yellow Signs: 035_1_0003.png
# Processing Yellow Signs: 035_1_0004.png
# Processing Yellow Signs: 036_1_0014.png
# Processing Yellow Signs: 036_1_0016.png
# Processing Yellow Signs: 036_1_0019.png
# Processing Yellow Signs: 037_0019.png
# Processing Yellow Signs: 037_0021.png
# Processing Yellow Signs: 037_1_0009.png
# Processing Yellow Signs: 038_0008.png
# Processing Yellow Signs: 040_0011.png
# Processing Yellow Signs: 042_0002_j.png
# Processing Yellow Signs: 042_0016_j.png
# Processing Yellow Signs: 043_1_0021.png
# Processing Yellow Signs: 045_1_0004.png
# Processing Yellow Signs: 045_1_0009.png
# Processing Yellow Signs: 046_0005_j.png
# Processing Yellow Signs: 047_0002.png
# Processing Yellow Signs: 047_0005.png
# Processing Yellow Signs: 047_1_0003.png
# Processing Yellow Signs: 048_0004.png
# Processing Yellow Signs: 049_1_0010.png
# Processing Yellow Signs: 050_1_0003.png
# Processing Yellow Signs: 051_0005_j.png
