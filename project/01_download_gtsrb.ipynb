# %% [markdown]
# # 01 — Download GTSRB Dataset
#
# Downloads the German Traffic Sign Recognition Benchmark (GTSRB) using torchvision.
#
# **Note:** This downloads ~300MB+ of images (plus archive). Data is saved to `../data/`.

# %%
from pathlib import Path
import torch
import torchvision
from torchvision.datasets import GTSRB

print(f"torch: {torch.__version__}")
print(f"torchvision: {torchvision.__version__}")
# Out:
# torch: 2.10.0
# torchvision: 0.25.0

# %%
DATA_DIR = Path("../data")
DATA_DIR.mkdir(parents=True, exist_ok=True)
print(f"Data directory: {DATA_DIR.resolve()}")
# Out:
# Data directory: C:\Users\Sova\Desktop\traffic-sign-recognition\data

# %%
train_dataset = GTSRB(root=DATA_DIR, split="train", download=True)
test_dataset = GTSRB(root=DATA_DIR, split="test", download=True)
# Out:
# 100.0%
# 100.0%
# 100.0%

# %%
image, label = train_dataset[0]
print(f"Train size: {len(train_dataset)}")
print(f"Test size:  {len(test_dataset)}")
print(f"Num classes: {len(train_dataset.classes)}")
print(f"Sample image: shape={tuple(image.size)} (PIL), label={label}")
# Out:
# Train size: 26640
# Test size:  12630
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 image, label = train_dataset[0]
#       2 print(f"Train size: {len(train_dataset)}")
#       3 print(f"Test size:  {len(test_dataset)}")
# ----> 4 print(f"Num classes: {len(train_dataset.classes)}")
#       5 print(f"Sample image: shape={tuple(image.size)} (PIL), label={label}")
#
# AttributeError: 'GTSRB' object has no attribute 'classes'
